# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create NumPy arrays for x and y values
y = np.array([6.69, 6.20, 5.72, 5.24, 4.77, 4.31, 3.85, 3.40])
x = np.array([1.50, 1.40, 1.30, 1.20,1.10, 1.00,  0.90, 0.80])
plt.scatter(x, y)
plt.xlabel('l')
plt.ylabel('T^2 ')
# Display plot
plt.show()
